# %%
import pandas as pd
import sklearn 
import scipy
from sklearn import linear_model as lm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cross_validation import KFold, train_test_split, cross_val_score, StratifiedKFold, LabelKFold, ShuffleSplit
from sklearn.metrics import roc_auc_score
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from mhcflurry.amino_acid import common_amino_acids
from mhcflurry import dataset
from mhcflurry.dataset import Dataset
import matplotlib.pyplot as plt 
% matplotlib inline
import numpy as np
import math 
from mhcflurry import peptide_encoding, amino_acid
import statsmodels.api as sm
from keras import models, layers, optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, Input, merge, Convolution1D, AveragePooling1D, Activation, Flatten
from keras.preprocessing import sequence
from keras.models import Model
from keras.engine import topology
import seaborn as sns
# Out:
# Using Theano backend.

# %%
df = pd.read_table("bdata.2009.mhci.public.1.txt")

df['log_meas']=1-np.log(df['meas'])/math.log(50000)
df['peptide_length'] = df['sequence'].str.len()


max_len=df['sequence'].str.len().max()
n_peptides = df['sequence'].count()

def amino_acid_hotshot_encoding(s):
    return common_amino_acids.hotshot_encoding([s],len(s)).flatten().astype(int)
df['hotshot_encoded_peptides'] = df.sequence.apply(lambda seq: amino_acid_hotshot_encoding(seq))

def amino_acid_index_encoding(s, maxlen):
    a = 1+common_amino_acids.index_encoding([s],len(s)).flatten()
    return np.concatenate([a, np.zeros(maxlen-len(a),dtype=int)])
df['index_encoded_peptides'] = df.sequence.apply(lambda seq: amino_acid_index_encoding(seq, max_len))

def measured_affinity_less_than(Y,k):
    IC50 = 50000**(1-Y)
    return (IC50 < k).astype(int) 

def affinity_label(Y):
    return measured_affinity_less_than(Y,50) + measured_affinity_less_than(Y,500) + measured_affinity_less_than(Y,5000) + measured_affinity_less_than(Y,50000)

df['affinity_label'] = affinity_label(df['log_meas'])
df_h = df[df['mhc']=='HLA-A-0201'][['hotshot_encoded_peptides','index_encoded_peptides','log_meas','peptide_length']]
X = np.array(list(df_h['index_encoded_peptides']))
y = np.array(list(df_h['log_meas']))
y[y<0]=0

# %%
folds = 3
batch_size_nn = 16
batch_size_lstm = 16
hidden = 50
dropout_probability = 0.25
embedding_dropout = 0.25
n_epochs = 100
epoch = 0


train_lstm100_aucs = np.zeros((folds,n_epochs))
test_lstm100_aucs = np.zeros((folds,n_epochs))


train_lstm011_aucs = np.zeros((folds,n_epochs))
test_lstm011_aucs = np.zeros((folds,n_epochs))


for i, (train_idx, test_idx) in enumerate(KFold(len(df_h),folds, shuffle=True)):
    
    sequence = Input( shape= (26, ),dtype='int32')
    embedded = Embedding(input_dim = 21, input_length = 26, output_dim= 32, dropout=embedding_dropout, mask_zero = True)(sequence)
    forwards = LSTM(hidden )(embedded)
    backwards = LSTM(hidden, go_backwards=True)(embedded)

    merged = merge([forwards, backwards], mode = 'concat', concat_axis=-1)
    after_dp = Dropout(dropout_probability)(merged)
    output = Dense(1, activation = 'sigmoid')(after_dp)
    
    lstm100 = Model(input = sequence, output = output)
    
    lstm100.compile(optimizer = 'adam', loss='mean_squared_error')
    
    sequence = Input( shape= (26, ),dtype='int32')
    embedded = Embedding(input_dim = 21, input_length = 26, output_dim= 32,mask_zero = True)(sequence)
    forwards = LSTM(hidden, dropout_W = 0.5, dropout_U = 0.5)(embedded)
    backwards = LSTM(hidden, dropout_W = 0.5,dropout_U = 0.5, go_backwards=True)(embedded)

    merged = merge([forwards, backwards], mode = 'concat', concat_axis=-1)
    after_dp = Dropout(dropout_probability)(merged)
    output = Dense(1, activation = 'sigmoid')(after_dp)
    lstm011 = Model(input = sequence, output = output)
    
    lstm011.compile(optimizer = 'adam', loss='mean_squared_error')
    
    for epoch in range(n_epochs):
        
        
        #lstm111ffn
        lstm100.fit(X[train_idx],y[train_idx], batch_size = batch_size_lstm, nb_epoch=1)
    
        train_lstm100_auc = roc_auc_score(measured_affinity_less_than(y[train_idx],500),lstm100.predict(X[train_idx]))
        test_lstm100_auc = roc_auc_score(measured_affinity_less_than(y[test_idx],500),lstm100.predict(X[test_idx]))
        
        train_lstm100_aucs[i][epoch]=train_lstm100_auc
        test_lstm100_aucs[i][epoch]=test_lstm100_auc
        
        #lstm111 
        lstm011.fit(X[train_idx],y[train_idx], batch_size = batch_size_lstm, nb_epoch=1)
    
        train_lstm011_auc = roc_auc_score(measured_affinity_less_than(y[train_idx],500),lstm011.predict(X[train_idx]))
        test_lstm011_auc = roc_auc_score(measured_affinity_less_than(y[test_idx],500),lstm011.predict(X[test_idx]))
        
        train_lstm011_aucs[i][epoch]=train_lstm011_auc
        test_lstm011_aucs[i][epoch]=test_lstm011_auc
        
        print(test_lstm100_auc, test_lstm011_auc, epoch, i)


train_lstm100_aucs_mean = np.mean(train_lstm111ffn_aucs, axis=0)
test_lstm100_aucs_mean = np.mean(test_lstm111ffn_aucs, axis=0)


train_lstm011_aucs_mean = np.mean(train_lstm111_aucs, axis=0)
test_lstm011_aucs_mean = np.mean(test_lstm111_aucs, axis=0)
# Out:
# Epoch 1/1
# 6376/6376 [==============================] - 11s - loss: 0.0724
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0721
# 0.862795652622 0.842995169082 0 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0616
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0580
# 0.893659252082 0.860084148579 1 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0567
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0558
# 0.921673641669 0.868212829518 2 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0474
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0537
# 0.931073522354 0.873181901776 3 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0463
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0508
# 0.933117579248 0.885709543866 4 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0450
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0476
# 0.937136615846 0.899753744298 5 0
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0443
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0446
# 0.939864267804 0.91842813505 6 0
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0439
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0403
# 0.940682877379 0.925694921032 7 0
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0431
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0375
# 0.941913707337 0.934097219419 8 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0445
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0366
# 0.940936309932 0.936703089186 9 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0435
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0351
# 0.940838076783 0.937237091761 10 0
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0423
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0341
# 0.944939198615 0.936438218526 11 0
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0432
# Epoch 1/1
# 6376/6376 [==============================] - 14s - loss: 0.0333
# 0.946482221594 0.939954426996 12 0
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.
# Epoch 1/1
# 6376/6376 [==============================] - 10s - loss: 0.0232
# 0.937991558229 0.949599666276 73 0
# Epoch 1/1
# 6376/6376 [==============================] - 8s - loss: 0.0309
# Epoch 1/1
# 6376/6376 [==============================] - 10s - loss: 0.0239
# 0.93789467074 0.950481521851 74 0
# Epoch 1/1
# 6376/6376 [==============================] - 8s - loss: 0.0310
# Epoch 1/1
# 6376/6376 [==============================] - 10s - loss: 0.0238
# 0.940272899762 0.950998255128 75 0
# Epoch 1/1
# 6376/6376 [==============================] - 9s - loss: 0.0330
# Epoch 1/1
# 6376/6376 [==============================] - 9s - loss: 0.0234
# 0.938982412229 0.951576440192 76 0
# Epoch 1/1
# 6376/6376 [==============================] - 9s - loss: 0.0312
# Epoch 1/1
# 6376/6376 [==============================] - 10s - loss: 0.0234
# 0.937423689888 0.951253033341 77 0
# Epoch 1/1
# 6376/6376 [==============================] - 9s - loss: 0.0314
# Epoch 1/1
# 6376/6376 [==============================] - 10s - loss: 0.0239
# 0.938057944101 0.951082134575 78 0
# Epoch 1/1
# 6376/6376 [==============================] - 9s - loss: 0.0311
# Epoch 1/1
# 6376/6376 [==============================] - 10s - loss: 0.0233
# 0.939418405932 0.950726431894 79 0
# Epoch 1/1
# 6376/6376 [==============================] - 9s - loss: 0.0308
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0236
# 0.9355913501 0.951224325937 80 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0302
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0233
# 0.938650482868 0.950793714873 81 0
# Epoch 1/1
# 6376/6376 [==============================] - 11s - loss: 0.0300
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0232
# 0.938840669421 0.950545664958 82 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0307
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0233
# 0.936051565675 0.95101395449 83 0
# Epoch 1/1
# 6376/6376 [==============================] - 11s - loss: 0.0290
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0237
# 0.937453742952 0.951136633788 84 0
# Epoch 1/1
# 6376/6376 [==============================] - 11s - loss: 0.0295
# Epoch 1/1
# 6376/6376 [==============================] - 13s - loss: 0.0231
# 0.937596382867 0.950870417468 85 0
# Epoch 1/1
# 6376/6376 [==============================] - 12s - loss: 0.0282
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e253c66a4037> in <module>()
#      51
#      52         train_lstm100_auc = roc_auc_score(measured_affinity_less_than(y[train_idx],500),lstm100.predict(X[train_idx]))
# ---> 53         test_lstm100_auc = roc_auc_score(measured_affinity_less_than(y[test_idx],500),lstm100.predict(X[test_idx]))
#      54
#      55         train_lstm100_aucs[i][epoch]=train_lstm100_auc
#
# /Users/giancarlokerg/anaconda/lib/python3.5/site-packages/Keras-1.0.5-py3.5.egg/keras/engine/training.py in predict(self, x, batch_size, verbose)
#    1153         f = self.predict_function
#    1154         return self._predict_loop(f, ins,
# -> 1155                                   batch_size=batch_size, verbose=verbose)
#    1156
#    1157     def train_on_batch(self, x, y,
#
# /Users/giancarlokerg/anaconda/lib/python3.5/site-packages/Keras-1.0.5-py3.5.egg/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose)
#     853                 ins_batch = slice_X(ins, batch_ids)
#     854
# --> 855             batch_outs = f(ins_batch)
#     856             if type(batch_outs) != list:
#     857                 batch_outs = [batch_outs]
#
# /Users/giancarlokerg/anaconda/lib/python3.5/site-packages/Keras-1.0.5-py3.5.egg/keras/backend/theano_backend.py in __call__(self, inputs)
#     529     def __call__(self, inputs):
#     530         assert type(inputs) in {list, tuple}
# --> 531         return self.function(*inputs)
#     532
#     533
#
# /Users/giancarlokerg/anaconda/lib/python3.5/site-packages/Theano-0.8.2-py3.5.egg/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /Users/giancarlokerg/anaconda/lib/python3.5/site-packages/Theano-0.8.2-py3.5.egg/theano/scan_module/scan_op.py in rval(p, i, o, n, allow_gc)
#     947         allow_gc = config.allow_gc and not self.allow_gc
#     948
# --> 949         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     950                  allow_gc=allow_gc):
#     951             r = p(n, [x[0] for x in i], o)
#
# KeyboardInterrupt:

# %%
plt.plot( np.arange(0,85,1), test_lstm100_aucs[0,0:85],color='b',marker='*', linestyle='-', label ="test LSTM 100")
plt.plot( np.arange(0,85,1), test_lstm011_aucs[0,0:85],color='r',marker='*', linestyle='-', label ="test LSTM 011")
plt.legend(loc=4)

# %%
plt.plot( np.arange(0,85,1), test_lstm100_aucs[0,0:85],color='b',marker='*', linestyle='-', label ="test LSTM 100")
plt.plot( np.arange(0,85,1), test_lstm011_aucs[0,0:85],color='r',marker='*', linestyle='-', label ="test LSTM 011")
plt.plot( np.arange(0,85,1), train_lstm100_aucs[0,0:85],color='y',marker='*', linestyle='-', label ="train LSTM 100")
plt.plot( np.arange(0,85,1), train_lstm011_aucs[0,0:85],color='g',marker='*', linestyle='-', label ="train LSTM 011")
plt.legend(loc=4)
